# %% [markdown]
# Homeassistant üzerinden gelen 30 günlük "telefon şarjda mı değil mi ?" data seti üzerinde yorumlamalar.

# %%
import pandas as pd

# %%
dataframe = pd.read_csv('Source/PhoneChargingState.csv')
dataframe
# Out:
#                                time  state.hour  state.value
# 0     2022-01-20T16:41:59.185+03:00         NaN            1
# 1     2022-01-20T16:43:05.585+03:00         NaN            0
# 2     2022-01-20T16:50:25.380+03:00         NaN            0
# 3     2022-01-20T17:14:38.861+03:00         NaN            1
# 4     2022-01-20T17:15:34.099+03:00         NaN            0
# ...                             ...         ...          ...
# 1737  2022-02-19T15:02:53.145+03:00         NaN            0
# 1738  2022-02-19T15:03:00.604+03:00         NaN            1
# 1739  2022-02-19T15:03:04.794+03:00         NaN            0
# 1740  2022-02-19T15:10:50.459+03:00         NaN            1
# 1741  2022-02-19T15:10:53.883+03:00         NaN            0
#
# [1742 rows x 3 columns]

# %%
dataframe.drop('state.hour',axis=1)
# Out:
#                                time  state.value
# 0     2022-01-20T16:41:59.185+03:00            1
# 1     2022-01-20T16:43:05.585+03:00            0
# 2     2022-01-20T16:50:25.380+03:00            0
# 3     2022-01-20T17:14:38.861+03:00            1
# 4     2022-01-20T17:15:34.099+03:00            0
# ...                             ...          ...
# 1737  2022-02-19T15:02:53.145+03:00            0
# 1738  2022-02-19T15:03:00.604+03:00            1
# 1739  2022-02-19T15:03:04.794+03:00            0
# 1740  2022-02-19T15:10:50.459+03:00            1
# 1741  2022-02-19T15:10:53.883+03:00            0
#
# [1742 rows x 2 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Untitled-1.ipynb Cell 5' in <module>
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000004untitled?line=0'>1</a> dataframe.columns['time']
#
# File D:\Python\lib\site-packages\pandas\core\indexes\base.py:4604, in Index.__getitem__(self, key)
#    <a href='file:///d%3A/Python/lib/site-packages/pandas/core/indexes/base.py?line=4601'>4602</a> if is_scalar(key):
#    <a href='file:///d%3A/Python/lib/site-packages/pandas/core/indexes/base.py?line=4602'>4603</a>     key = com.cast_scalar_indexer(key, warn_float=True)
# -> <a href='file:///d%3A/Python/lib/site-packages/pandas/core/indexes/base.py?line=4603'>4604</a>     return getitem(key)
#    <a href='file:///d%3A/Python/lib/site-packages/pandas/core/indexes/base.py?line=4605'>4606</a> if isinstance(key, slice):
#    <a href='file:///d%3A/Python/lib/site-packages/pandas/core/indexes/base.py?line=4606'>4607</a>     # This case is separated from the conditional above to avoid
#    <a href='file:///d%3A/Python/lib/site-packages/pandas/core/indexes/base.py?line=4607'>4608</a>     # pessimization of basic indexing.
#    <a href='file:///d%3A/Python/lib/site-packages/pandas/core/indexes/base.py?line=4608'>4609</a>     result = getitem(key)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
